# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Total population, N.
N = 1
# Initial number of infected and recovered individuals, I0, R0 and V0 .
I0, R0, V0 = 0.0001, 0, 0
# Everyone else, S0, is susceptible to infection initially.
S0 = N - I0 - R0 - V0
# s = S0/N
# i = I0/N
# v = V0/N
# r = R0/N
# Model parameters
alpha=  0.000035342      #Birth rate
beta = 0.03              #Infection per day
omega= 1/3650            #Rate of first dose of vacination
gamma= 0.0476            #Recovered rate
roh=  1/4380             #Time between first and second dose
psi= 0.00020185          #first dose wanes in immunity
mu= 0.000035342          # Death rate
# A grid of time points (in days)
t = np.linspace(0, 200000, 200000)

# The SIR model differential equations.
def model(y, t, alpha ,beta, gamma, mu, roh,psi, omega):
    s, i, v, r = y
    dsdt = -mu*s + mu*N - psi*s + omega*v - beta*i*s  
    didt = -mu*i + beta*i*s - gamma*i
    dvdt = -mu*v + psi*s - omega*v - roh*v
    drdt = gamma*i - mu*r + roh*v
    
    
    return dsdt, didt, dvdt, drdt

# Initial conditions vector
# y0 = S0, I0, R0, V0
y0 = S0, I0, V0, R0
# Integrate the SIR equations over the time grid, t.def 
sol = odeint(model, y0, t, args=(alpha ,beta, gamma, mu, roh, psi, omega))
# S, I, R, v = sol.T




# Extract the results
s = sol[:, 0]
i = sol[:, 1]
v = sol[:, 2]
r = sol[:, 3]


# Plot the results
plt.plot(t, s, label='Susceptible')
plt.plot(t, i, label='Infected')
plt.plot(t, v, label='Vaccinated')
plt.plot(t, r, label= 'Recoverd' )
plt.xlabel('Time')
plt.ylabel('Population')
plt.legend()
plt.grid(True)
plt.show()


# print(max(s))
# print(max(i))
# print(max(v))
# print("min S", min(s))
# print("min I", min(i))
# print("min V",min(v))

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Total population, N.
N = 1
# Initial number of infected and recovered individuals, I0, R0 and V0 .
I0, R0, V0 = 0.0001, 0, 0
# Everyone else, S0, is susceptible to infection initially.
S0 = N - I0 - R0 - V0
s = S0/N
i = I0/N
v = V0/N
# Model parameters
alpha=  0.000035342      #Birth rate
beta = 0.261994381           #Infection per day
omega= 1/3650         #Rate of first dose of vacination
gamma= 0.0476           #Recovered rate
roh=  1/4380           #Time between first and second dose
psi= 0.000471498            #first dose wanes in immunity
mu= 0.000035342          # Death rate
# A grid of time points (in days)
t = np.linspace(0, 2000, 2000)

# The SIR model differential equations.
def model(y, t, alpha ,beta, gamma, mu, roh,psi, omega):
    s, i, v = y
    dsdt = -mu*s + mu - psi*s + omega*v - beta*i*s  
    didt = -mu*i + beta*i*s - gamma*i
    dvdt = -mu*v + psi*s - omega*v - roh*v
    
    
    return dsdt, didt, dvdt

# Initial conditions vector
# y0 = S0, I0, R0, V0
y0 = S0, I0, V0
# Integrate the SIR equations over the time grid, t.def 
sol = odeint(model, y0, t, args=(alpha ,beta, gamma, mu, roh, psi, omega))
# S, I, R, v = sol.T




# Extract the results
s = sol[:, 0]
i = sol[:, 1]
v = sol[:, 2]


# Plot the results
plt.plot(t, s, label='Susceptible')
plt.plot(t, i, label='Infected')
plt.plot(t, v, label='Vaccinated')
plt.xlabel('Time')
plt.ylabel('Population')
plt.legend()
plt.grid(True)
plt.show()


print(max(s))
print(max(i))
print(max(v))
print("min S", min(s))
print("min I", min(i))
print("min V",min(v))
# Out:
# 0.9999
# 0.49311146705094605
# 0.027035589630165287
# min S 0.006553624932419511
# min I -1.5688411650316623e-08
# min V 0.0

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Total population, N.
N = 1
# Initial number of infected and recovered individuals, I0, R0 and V0 .
I0, R0, V0 = 0.0001, 0, 0
# Everyone else, S0, is susceptible to infection initially.
S0 = N - I0 - R0 - V0
s = S0/N
i = I0/N
v = V0/N
# Model parameters
alpha=  0.000035342      #Birth rate
beta = 0.261994381           #Infection per day
omega= 1/10950         #Rate of first dose of vacination
gamma= 0.0476           #Recovered rate
roh=  0           #Time between first and second dose
psi= 0.00020185            #first dose wanes in immunity
mu= 0.000035342          # Death rate
# A grid of time points (in days)
t = np.linspace(0, 1000, 1000)

# The SIR model differential equations.
def model(y, t, alpha ,beta, gamma, mu, roh,psi, omega):
    s, i, v = y
    dsdt = -mu*s + mu - psi*s + omega*v - beta*i*s  
    didt = -mu*i + beta*i*s - gamma*i
    dvdt = -mu*v + psi*s - omega*v - roh*v
    
    
    return dsdt, didt, dvdt

# Initial conditions vector
# y0 = S0, I0, R0, V0
y0 = S0, I0, V0
# Integrate the SIR equations over the time grid, t.def 
sol = odeint(model, y0, t, args=(alpha ,beta, gamma, mu, roh, psi, omega))
# S, I, R, v = sol.T




# Extract the results
s = sol[:, 0]
i = sol[:, 1]
v = sol[:, 2]


# Plot the results
plt.plot(t, s, label='Susceptible')
plt.plot(t, i, label='Infected')
plt.plot(t, v, label='Vaccinated')
plt.xlabel('Time')
plt.ylabel('Population')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Total population, N.
N = 1
# Initial number of infected and recovered individuals, I0, R0 and V0 .
I0, R0, V0 = 0.0001, 0, 0
# Everyone else, S0, is susceptible to infection initially.
S0 = N - I0 - R0 - V0
s = S0/N
i = I0/N
v = V0/N
r = R0/N
# Model parameters
alpha=  0.000035342      #Birth rate
beta = 0.03           #Infection per day
psi= 1/3650         #Rate of first dose of vacination
gamma= 0.0476           #Recovered rate
roh=  1/4380           #Time between first and second dose
omega= 0.00020185            #first dose wanes in immunity
mu= 0.000035342          # Death rate
# A grid of time points (in days)
t = np.linspace(0, 200000, 2000000)

# The SIR model differential equations.
def model(y, t, alpha ,beta, gamma, mu, roh,psi, omega):
    s, i, v, r = y
    dsdt = -mu*s + mu - omega*s + psi*v - beta*i*s  
    didt = -mu*i + beta*i*s - gamma*i
    dvdt = -mu*v + omega*s - psi*v - roh*v
    drdt = gamma*i - mu*r + roh*v
    
    
    return dsdt, didt, dvdt, drdt

# Initial conditions vector
# y0 = S0, I0, R0, V0
y0 = S0, I0, V0, R0
# Integrate the SIR equations over the time grid, t.def 
sol = odeint(model, y0, t, args=(alpha ,beta, gamma, mu, roh, psi, omega))
# S, I, R, v = sol.T




# Extract the results
s = sol[:, 0]
i = sol[:, 1]
v = sol[:, 2]
r = sol[:, 3]


# Plot the results
plt.plot(t, s, label='Susceptible')
plt.plot(t, i, label='Infected')
plt.plot(t, v, label='Vaccinated')
plt.plot(t, r, label= 'Recoverd' )
plt.xlabel('Time')
plt.ylabel('Population')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Total population, N.
N = 1
# Initial number of infected and recovered individuals, I0, R0 and V0 .
I0, R0, V0 = 0.0001, 0, 0
# Everyone else, S0, is susceptible to infection initially.
S0 = N - I0 - R0 - V0
s = S0/N
i = I0/N
v = V0/N
r = R0/N
# Model parameters
alpha=  0.000035342      #Birth rate
beta = 0.261994381           #Infection per day
psi= 1/3650         #Rate of first dose of vacination
gamma= 0.0476          #Recovered rate
roh=  1/4380           #Time between first and second dose
omega= 0.000471498            #first dose wanes in immunity
mu= 0.000035342          # Death rate
# A grid of time points (in days)
t = np.linspace(0, 1000, 1000)

# The SIR model differential equations.
def model(y, t, alpha ,beta, gamma, mu, roh,psi, omega):
    s, i, v, r = y
    dsdt = -mu*s + mu - omega*s + psi*v - beta*i*s  
    didt = -mu*i + beta*i*s - gamma*i
    dvdt = -mu*v + omega*s - psi*v - roh*v
    drdt = gamma*i - mu*r + roh*v
    
    
    return dsdt, didt, dvdt, drdt

# Initial conditions vector
# y0 = S0, I0, R0, V0
y0 = S0, I0, V0, R0
# Integrate the SIR equations over the time grid, t.def 
sol = odeint(model, y0, t, args=(alpha ,beta, gamma, mu, roh, psi, omega))
# S, I, R, v = sol.T




# Extract the results
s = sol[:, 0]
i = sol[:, 1]
v = sol[:, 2]
r = sol[:, 3]


# Plot the results
plt.plot(t, s, label='Susceptible')
plt.plot(t, i, label='Infected')
plt.plot(t, v, label='Vaccinated')
plt.plot(t, r, label= 'Recoverd' )
plt.xlabel('Time')
plt.ylabel('Population')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Total population, N.
N = 1
# Initial number of infected and recovered individuals, I0, R0 and V0 .
I0, R0, V0 = 0.0001, 0, 0
# Everyone else, S0, is susceptible to infection initially.
S0 = N - I0 - R0 - V0
s = S0/N
i = I0/N
v = V0/N
r = R0/N
# Model parameters
alpha=  0.000035342      #Birth rate
beta = 0.261994381           #Infection per day
psi= 1/3650         #Rate of first dose of vacination
gamma= 0.0476          #Recovered rate
roh=  1/4380           #Time between first and second dose
omega= 0.00020185            #first dose wanes in immunity
mu= 0.000035342          # Death rate
# A grid of time points (in days)
t = np.linspace(0, 1000, 1000)

# The SIR model differential equations.
def model(y, t, alpha ,beta, gamma, mu, roh,psi, omega):
    s, i, v, r = y
    dsdt = -mu*s + mu - omega*s + psi*v - beta*i*s  
    didt = -mu*i + beta*i*s - gamma*i
    dvdt = -mu*v + omega*s - psi*v - roh*v
    drdt = gamma*i - mu*r + roh*v
    
    
    return dsdt, didt, dvdt, drdt

# Initial conditions vector
# y0 = S0, I0, R0, V0
y0 = S0, I0, V0, R0
# Integrate the SIR equations over the time grid, t.def 
sol = odeint(model, y0, t, args=(alpha ,beta, gamma, mu, roh, psi, omega))
# S, I, R, v = sol.T




# Extract the results
s = sol[:, 0]
i = sol[:, 1]
v = sol[:, 2]
r = sol[:, 3]
print(len(s))

# Plot the results
plt.plot(t, s, label='Susceptible')
plt.plot(t, i, label='Infected')
plt.plot(t, v, label='Vaccinated')
plt.plot(t, r, label= 'Recoverd' )
plt.xlabel('Time')
plt.ylabel('Population')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 1000

# %%
print(len(sol))
# Out:
# 1000
